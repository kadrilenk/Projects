# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# I first create a 10x500 data frame where the values are randomly 0 or 1. Then I calculate the cumulative sum for each column and divide the sum by the corresponding row number. This gives me the proportion of ones that have occurred so far in the column.

# %%
random = pd.DataFrame(np.random.randint(0,2,size=(500, 10)))
rows = np.arange(1, 501)
result = random.cumsum().divide(rows, axis=0)
result.head()
# Out:
#      0         1         2         3         4         5         6     7  \
# 0  1.0  0.000000  1.000000  0.000000  1.000000  1.000000  1.000000  0.00
# 1  1.0  0.000000  0.500000  0.000000  0.500000  0.500000  0.500000  0.00
# 2  1.0  0.333333  0.333333  0.333333  0.666667  0.666667  0.666667  0.00
# 3  1.0  0.500000  0.500000  0.250000  0.750000  0.500000  0.500000  0.25
# 4  0.8  0.400000  0.600000  0.200000  0.600000  0.400000  0.600000  0.40
#
#           8         9
# 0  1.000000  0.000000
# 1  0.500000  0.500000
# 2  0.333333  0.666667
# 3  0.500000  0.500000
# 4  0.400000  0.600000

# %% [markdown]
# And then let's visualize.

# %%
# plt.figure(figsize=(15,5))
fig,ax = plt.subplots(figsize = (15, 5))

for i in range(10):
    plt.plot(rows, result[i])

plt.gca().set_xlim(0, 300)
plt.gca().set_ylim(0, 1)
plt.grid(1)

# plt.savefig('head_and_tails.png', bbox_inches='tight', dpi=200)

plt.show()
